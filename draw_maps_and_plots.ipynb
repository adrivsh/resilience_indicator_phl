# %% [markdown]
# This notebook illustrates some results

# %%
# %reset-f

# %%
# %load_ext autoreload
# %autoreload
# %matplotlib inline

# %%
from maps_lib import *
import pandas as pd
from IPython.display import Image

# %%
df_with_results = pd.read_csv("df.csv",index_col=0)
df_with_results.head()
# Out:
#                   gdp_pc_pp             pop    plgp  unemp     bashs  \
# Province
# Abra                133.688   240135.244121  0.8827  0.165  0.857720
# Agusan Del Norte    179.014   661728.454375  0.7075  0.210  0.921445
# Agusan Del Sur      126.492   677779.682154  0.6871  0.210  0.727442
# Apayao              158.732   116022.676390  0.6813  0.165  0.814192
# Batangas            219.272  2485002.055465  0.8330  0.175  0.819596
#
#                   pov_head      shew      ophe  gdp_pc_pp_nat  rel_gdp_pp  \
# Province
# Abra              0.373595  0.953416  0.031414     184.136685    0.726026
# Agusan Del Norte  0.346715  0.821277  0.034563     184.136685    0.972180
# Agusan Del Sur    0.480785  0.821277  0.034563     184.136685    0.686946
# Apayao            0.613667  0.953416  0.031414     184.136685    0.862034
# Batangas          0.190351  1.117207  0.034849     184.136685    1.190811
#
#                        ...        deltaW_nat  equivalent_cost      risk  \
# Province               ...
# Abra                   ...          0.000493         1.218217  0.009112
# Agusan Del Norte       ...          0.003865         3.513482  0.019627
# Agusan Del Sur         ...          0.000833         1.150511  0.009096
# Apayao                 ...          0.000006         0.051866  0.000327
# Batangas               ...          0.000121         0.020125  0.000092
#
#                   total_equivalent_cost  total_equivalent_cost_of_nat_buyout  \
# Province
# Abra                      292536.942611                           250.694787
# Agusan Del Norte         2324971.035897                          6090.633997
# Agusan Del Sur            779793.173142                          1467.443833
# Apayao                      6017.676082                             2.222262
# Batangas                   50011.830069                           885.731452
#
#                   resilience  resilience_no_shock  \
# Province
# Abra                0.555923             0.556400
# Agusan Del Norte    0.615612             0.617225
# Agusan Del Sur      0.432071             0.432884
# Apayao              0.496068             0.496252
# Batangas            1.091834             1.111171
#
#                   resilience_no_shock_no_uspcale  resilience_no_shock_no_SP  \
# Province
# Abra                                    0.516817                   0.448986
# Agusan Del Norte                        0.487129                   0.345018
# Agusan Del Sur                          0.309596                   0.199328
# Apayao                                  0.453814                   0.384128
# Batangas                                1.009102                   0.868775
#
#                   risk_to_assets
# Province
# Abra                    0.005066
# Agusan Del Norte        0.012083
# Agusan Del Sur          0.003930
# Apayao                  0.000162
# Batangas                0.000100
#
# [5 rows x 63 columns]

# %%
map_with_r(100*df_with_results,"map_of_risk_to_assets.png",shapefile="inputs/PHL_adm1.shp",to_map="risk_to_assets",
           legend_name="Risk to assets", color_palette="brewer.pal(5,'BuPu')",na_color = "light grey")
Image("map_of_risk_to_assets.png",width=400)
# Out:
# Making the map....
# Map done
# There was no data for the following districts: aklan, albay, antique, aurora, basilan, bataan, batanes, benguet, biliran, bohol, camarines norte, camiguin, catanduanes, cavite, cebu, compostela valley, davao del sur, davao oriental, dinagat islands, eastern samar, guimaras, iloilo, leyte, marinduque, masbate, metropolitan manila, misamis occidental, misamis oriental, mountain province, negros oriental, northern samar, occidental mindoro, oriental mindoro, palawan, quirino, romblon, shariff kabunsuan, siquijor, sorsogon, southern leyte, sulu, surigao del norte, surigao del sur, tawi-tawi, zambales, zamboanga del norte, zamboanga sibugay

# %%
map_with_r(100*df_with_results.risk,"map_of_risk.png",shapefile="inputs/PHL_adm1.shp",to_map="risk",
           legend_name="Risk to well-being", color_palette="brewer.pal(5,'YlOrRd')",na_color = "light grey")
Image("map_of_risk.png",width=400)
# Out:
# Making the map....
# Map done
# There was no data for the following districts: aklan, albay, antique, aurora, basilan, bataan, batanes, benguet, biliran, bohol, camarines norte, camiguin, catanduanes, cavite, cebu, compostela valley, davao del sur, davao oriental, dinagat islands, eastern samar, guimaras, iloilo, leyte, marinduque, masbate, metropolitan manila, misamis occidental, misamis oriental, mountain province, negros oriental, northern samar, occidental mindoro, oriental mindoro, palawan, quirino, romblon, shariff kabunsuan, siquijor, sorsogon, southern leyte, sulu, surigao del norte, surigao del sur, tawi-tawi, zambales, zamboanga del norte, zamboanga sibugay

# %%
map_with_r(100*df_with_results.resilience,"map_of_resilience.png",shapefile="inputs/PHL_adm1.shp",to_map="resilience",legend_name="Capacity",
           color_palette="rev(brewer.pal(5,'Blues'))",na_color = "light grey")  
Image("map_of_resilience.png",width=400)
# Out:
# Making the map....
# Map done
# There was no data for the following districts: aklan, albay, antique, aurora, basilan, bataan, batanes, benguet, biliran, bohol, camarines norte, camiguin, catanduanes, cavite, cebu, compostela valley, davao del sur, davao oriental, dinagat islands, eastern samar, guimaras, iloilo, leyte, marinduque, masbate, metropolitan manila, misamis occidental, misamis oriental, mountain province, negros oriental, northern samar, occidental mindoro, oriental mindoro, palawan, quirino, romblon, shariff kabunsuan, siquijor, sorsogon, southern leyte, sulu, surigao del norte, surigao del sur, tawi-tawi, zambales, zamboanga del norte, zamboanga sibugay

# %% [markdown]
# # Some basic plots

# %%
x = 100*df_with_results.risk
y = 100*df_with_results.resilience

plt.scatter(x,y)

plt.xlabel("Risk to welfare (%)")
plt.ylabel("Resilience (%)")

plt.xlim(0)
plt.ylim(0);

# %%
x = 100*df_with_results.risk
y = 100*df_with_results.risk_to_assets

plt.scatter(y,x)

plt.ylabel("Risk to welfare (%)")
plt.xlabel("Risk to assets (%)")

plt.title("Lack of socio economic capacity can worsen risk")

plt.xlim(0,2)
plt.ylim(0)

plt.savefig("risk_assets_and_welfare.png")

plt.plot([0, 2],[0, 2], "--")

plt.savefig("risk_assets_and_welfare-1.png")

plt.annotate("",
            xy=(0.6, 0.6), xycoords='data',
            xytext=(0.6, 2.4), textcoords='data',
            arrowprops=dict(arrowstyle="<->",
                            connectionstyle="arc3", color="red"),
            )


plt.savefig("risk_assets_and_welfare-2.png")
