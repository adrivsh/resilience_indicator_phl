# %%
# %reset-f

# %%
# %load_ext autoreload
# %autoreload
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from maps_lib import *
import pandas as pd
from IPython.display import Image

# %%
df_with_results = pd.read_csv("df.csv",index_col=0)
df_with_results.head()
# Out:
#                       ophe     bashs  unemp             pop      shew  \
# Province
# Abra              0.031414  0.857720  0.165   240135.244121  0.652174
# Agusan Del Norte  0.034563  0.921445  0.210   661728.454375  0.395745
# Agusan Del Sur    0.034563  0.727442  0.210   677779.682154  0.395745
# Aklan             0.044318  0.806176  0.188   554414.442422  0.548898
# Albay             0.032568  0.840840  0.346  1264097.894966  0.514019
#
#                   pov_head  gdp_pc_pp    plgp  gdp_pc_pp_nat  gdp_pc_pp_ref  \
# Province
# Abra              0.373595    133.688  0.8827     184.136685        133.688
# Agusan Del Norte  0.346715    179.014  0.7075     184.136685        179.014
# Agusan Del Sur    0.480785    126.492  0.6871     184.136685        126.492
# Aklan             0.249662    119.962  0.7210     184.136685        119.962
# Albay             0.409587    158.629  0.7930     184.136685        158.629
#
#                        ...            risk  total_equivalent_cost  \
# Province               ...
# Abra                   ...        0.022842          733308.534933
# Agusan Del Norte       ...        0.045458         5384912.411523
# Agusan Del Sur         ...        0.025916         2221841.711196
# Aklan                  ...             NaN                    NaN
# Albay                  ...             NaN                    NaN
#
#                   total_equivalent_cost_of_destitution  \
# Province
# Abra                                        660.087305
# Agusan Del Norte                          48921.270942
# Agusan Del Sur                            39668.914843
# Aklan                                              NaN
# Albay                                              NaN
#
#                   total_equivalent_cost_no_destitution  \
# Province
# Abra                                     732648.447628
# Agusan Del Norte                        5335991.140581
# Agusan Del Sur                          2182172.796353
# Aklan                                              NaN
# Albay                                              NaN
#
#                   total_equivalent_cost_of_nat_buyout  resilience  \
# Province
# Abra                                       181.418843    0.274121
# Agusan Del Norte                          5302.814295    0.395668
# Agusan Del Sur                            1536.377822    0.271336
# Aklan                                             NaN         NaN
# Albay                                             NaN         NaN
#
#                   resilience_no_shock  resilience_no_shock_no_uspcale  \
# Province
# Abra                         0.274436                        0.261618
# Agusan Del Norte             0.399689                        0.337576
# Agusan Del Sur               0.276459                        0.237278
# Aklan                             NaN                             NaN
# Albay                             NaN                             NaN
#
#                   resilience_no_shock_no_SP  risk_to_assets
# Province
# Abra                               0.237178        0.006262
# Agusan Del Norte                   0.256966        0.017986
# Agusan Del Sur                     0.184508        0.007032
# Aklan                                   NaN             NaN
# Albay                                   NaN             NaN
#
# [5 rows x 82 columns]

# %%
map_with_r(100*df_with_results,"map_of_risk_to_assets.png",shapefile="PHL_adm1.shp",to_map="risk_to_assets",
           legend_name="Risk to assets", color_palette="brewer.pal(5,'BuPu')",na_color = "light grey")
Image("map_of_risk_to_assets.png",width=400)
# Out:
# Making the map....
# None b''
# There was no data for the following districts: laguna, lanao del norte, metropolitan manila, shariff kabunsuan

# %%
map_with_r(100*df_with_results.risk,"map_of_risk.png",shapefile="PHL_adm1.shp",to_map="risk",
           legend_name="Risk to well-being", color_palette="brewer.pal(5,'YlOrRd')",na_color = "light grey")
Image("map_of_risk.png",width=400)
# Out:
# Making the map....
# None b''
# There was no data for the following districts: laguna, lanao del norte, metropolitan manila, shariff kabunsuan

# %%
map_with_r(100*df_with_results.resilience,"map_of_resilience.png",shapefile="PHL_adm1.shp",to_map="resilience",legend_name="Capacity",
           color_palette="rev(brewer.pal(5,'Blues'))",na_color = "light grey")  
Image("map_of_resilience.png",width=400)
# Out:
# Making the map....
# None b''
# There was no data for the following districts: laguna, lanao del norte, metropolitan manila, shariff kabunsuan

# %% [markdown]
# # Some basic plots

# %%
x = 100*df_with_results.risk
y = 100*df_with_results.resilience

plt.scatter(x,y)

plt.xlabel("Risk to welfare (%)")
plt.ylabel("Resilience (%)")

plt.xlim(0)
plt.ylim(0);

# %%
x = 100*df_with_results.risk
y = 100*df_with_results.risk_to_assets

plt.scatter(y,x)

plt.ylabel("Risk to welfare (%)")
plt.xlabel("Risk to assets (%)")

plt.title("Lack of socio economic capacity can worsen risk")

plt.xlim(0,2)
plt.ylim(0)

plt.savefig("risk_assets_and_welfare.png")

plt.plot([0, 2],[0, 2], "--")

plt.savefig("risk_assets_and_welfare-1.png")

plt.annotate("",
            xy=(0.6, 0.6), xycoords='data',
            xytext=(0.6, 2.4), textcoords='data',
            arrowprops=dict(arrowstyle="<->",
                            connectionstyle="arc3", color="red"),
            )


plt.savefig("risk_assets_and_welfare-2.png")
