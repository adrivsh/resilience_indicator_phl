# %% [markdown]
# transforms a shapefile with admnistrative boundaries to SVG conserving attributes

# %%
import matplotlib.pylab as plt
import geopandas as gpd
import fiona
# %matplotlib inline

# %%
shp=gpd.read_file("VNM_adm/VNM_adm1.shp")

plt.figure(figsize=(9,9))
shp.plot()
plt.axes("off")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c563ca963c5a> in <module>()
#       3 plt.figure(figsize=(9,9))
#       4 shp.plot()
# ----> 5 plt.axes("off")
#
# C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\pyplot.py in axes(*args, **kwargs)
#     874     else:
#     875         rect = arg
# --> 876         a = gcf().add_axes(rect, **kwargs)
#     877     return a
#     878
#
# C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\figure.py in add_axes(self, *args, **kwargs)
#     913
#     914             # create the new axes using the axes class given
# --> 915             a = projection_class(self, rect, **kwargs)
#     916
#     917         self._axstack.add(key, a)
#
# C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     475             self._position = rect
#     476         else:
# --> 477             self._position = mtransforms.Bbox.from_bounds(*rect)
#     478         self._originalPosition = self._position.frozen()
#     479         # self.set_axes(self)
#
# TypeError: from_bounds() missing 1 required positional argument: 'height'

# %% [markdown]
# ## Kartograph

# %%
from string import Template
from subprocess import call
import os
from bs4 import BeautifulSoup

# %%
os.path.splitext("VNM_adm/VNM_adm1.shp")
# Out:
# ('VNM_adm/VNM_adm1', '.shp')

# %%
my_shapefile_path = "VNM_adm/VNM_adm1.shp"
my_reg_id = "ProvName"
target_svg = 'BlankSimpleMapVN.svg'
my_svg_title = "Map of the Philippines"
k_config_model = 'kartograph_config_model.json'


#Temp file names
file, ext = os.path.splitext(target_svg)
tmp_svg_file = file+"_raw"+ext
tmp_config_file = "katograph_config_tmp.json"

#get generic Kartograph configuration
with open(k_config_model, 'r') as myfile:
    katograph_config_model=myfile.read()

#specifies K config with user paramters   
katograph_config = Template(katograph_config_model).safe_substitute(
    shapefile_path=my_shapefile_path, region_identifier=my_reg_id) #use Template to format a string that contains extra curly brackets
#writes the config file 
with open(tmp_config_file, "w") as text_file:
    text_file.write(katograph_config)

#calls Kartograph 
err= call("activate py2 & kartograph "+tmp_config_file+" -o "+tmp_svg_file, shell=True)
if err>0:
    print("error " + err)


### POST-PROCESSES THE KARTOGRAPH SVG: DATA-CLASS TO CLASS AND PRETTY INDENTATION

#opens 
with open(tmp_svg_file, 'r', encoding='utf8') as svgfile:
    thesvg = svgfile.read()

#parses the SVG (an XML file)
soup=BeautifulSoup(thesvg,"xml")

#renames all the "data-class" from Kartograph to "class" and gives them a title (for mouse hover)
for path in soup.findAll("path"):
    path["class"]=path["data-class"]
    del path["data-class"]
    p_title = soup.new_tag("title")
    p_title.string = path["class"]
    path.insert(1,p_title)

#gives a class to the big shape (wont work if there are oceans as they will get default format)    
for g in soup.findAll("g"):
    g["class"]  = g["id"]    

#Add a title to the whole SVG    
new_title =soup.new_tag("title")
new_title.string= my_svg_title
soup.svg.insert(1,new_title)

#deletes "pretty print" and enable_background attirbutes (unimportant)
del soup.svg["pretty_print"]
del soup.svg["enable_background"]

#OVERWRITES the initial SVG with the new SVG    
with open(target_svg, 'w',  encoding='utf8') as svgfile:
    svgfile.write(soup.prettify())


#deletes temp files

#Kartograph config
if os.path.exists(tmp_config_file):
    try:
        os.remove(tmp_config_file)
    except:
        pass

#Unformated SVG    
if os.path.exists(tmp_svg_file):
    try:
        os.remove(tmp_svg_file)   
    except:
        pass

# %%
shp_to_svg("phl_polbnda_adm2_gsi.shp")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-f7f4e880b9ed> in <module>()
# ----> 1 shp_to_svg("phl_polbnda_adm2_gsi.shp")
#
# <ipython-input-2-5cf5b4e03993> in shp_to_svg(my_shapefile_path, my_reg_id, target_svg, my_svg_title, k_config_model)
#      36     #renames all the "data-class" from Kartograph to "class" and gives them a title (for mouse hover)
#      37     for path in soup.findAll("path"):
# ---> 38         path["class"]=path["data-class"]
#      39         del path["data-class"]
#      40         p_title = soup.new_tag("title")
#
# C:\Users\Admin\Anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#     956         """tag[key] returns the value of the 'key' attribute for the tag,
#     957         and throws an exception if it's not there."""
# --> 958         return self.attrs[key]
#     959
#     960     def __iter__(self):
#
# KeyError: 'data-class'
